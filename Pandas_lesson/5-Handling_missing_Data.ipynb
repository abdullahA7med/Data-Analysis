# %% [markdown]
# # Pandas 🐼

# %% [markdown]
# ## Handlig missing Data.
#
# **how can i deal with missing data**

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("ramen-ratings.csv")
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# **as we know some time we get dataSet with Null(NAN) values**
#
# #### why we have Null:
#  - **maybe becouse the man which entery data not type it of that info not avilable for him**
#
# - **we have some ways to deal with Null(NaN)**

# %% [markdown]
# -------------------------
#
#
# # our methods
#
#
# -------------------------

# %% [markdown]
# **lets check if we have Null(NaN) values in my dataFrame(DataSet)**
#
# - **From last method i learned 2 method to know Null values.**
#
#     - isnull()  => return True, if it wall Null.
#
#     - notnull() => return False, if it was'nt Null.
#
# - **when i check my Data, i check all not 1 column or 2.**

# %%
# do you remember -> sum function <- from numpy lesson.
# it summation my values


# now i use ut again To know the summation values in my data.
df.isnull().sum()

# now it displayed, how much Null in each column.
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %% [markdown]
# - **Now shoud take a dission, did you will remove that Rows which have null Value. |OR|  you need fill null value, by anouth value**
#
# Here have Two method, dropna() | Or | fillna()
#
# - **to take a dission shoud check some details**
#
#
#     - did the numbers of rows which have Null, is very big, in our case -> Top Ten column <- most Rows have null,
#       - if i droped it, i removed 2539 rows from my data, which have 2580 | i lost many (will effect in my model)
#
#       - So that i fill that Rows by anouther valued.
#
#         ....
#
#
#     - but in case of -> Style <- have just 2 rows which have null| if i removed them, not have a big effect, like -> Top Ten <-

# %% [markdown]
# 1) ### dropna()
#
# - **jop of it -> drop Row/column which have null(NaN) or any missing data**

# %% [markdown]
# Drop the Rows that have NaN.

# %%
df.dropna() # here droped all rows, which have NaN.
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %% [markdown]
# **dropna, have some parameters**
#
# - **Like**
#     - axis -> remove that column which have NaN => we use axis, like in numpy
#         - axis=0 (defoult) => delete rows.
#         - axis=1           => delete column.
#
#     - subset()

# %%
df.dropna(axis=1) # delet column

df.dropna(axis='columns') # delet column

# delete any column have NaN.
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety   Country Stars
# 0                             T's Restaurant Tantanmen      Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor    Taiwan  2.75
# 4                                       Singapore Curry     India  3.75
# ...                                                 ...       ...   ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...   Vietnam   3.5
# ...

# %% [markdown]
# **now if typed df changes not applayed.**
#
# - to applay it do -> reassign to your data frame (Recommended-> creat new var To store new DataFrame)
# -  |OR|
# -   use param of -> inplace make it True <-

# %% [markdown]
# -----------------------
#
#
# Next method.
#
#
# ------------------------

# %% [markdown]
# 2) ### fillna()
#
#
# **Jop of it**
#
# - **when you need to fill NaN by specific value.**

# %%
# will fill any NaN in dataFrame by entry value. 

df1 = df.fillna(0)

# %%
df1.loc[df1['Style'] == 0]
# Out:
#       Review #   Brand            Variety Style Country Stars Top Ten
# 2152       428  Kamfen     E Menm Chicken     0   China  3.75       0
# 2442       138    Unif  100 Furong Shrimp     0  Taiwan     3       0

# %%
df1.loc[df1['Style'] == 0]

# now all rows in style column (which have null) will equal 0.
# Out:
#       Review #   Brand            Variety Style Country Stars Top Ten
# 2152       428  Kamfen     E Menm Chicken     0   China  3.75       0
# 2442       138    Unif  100 Furong Shrimp     0  Taiwan     3       0

# %%
# ////////////// keep going ... ////////////////////////

# %% [markdown]
# **What if i need**
#
# - **in Top Ten column -> i need make Null values equla specific value (ex => 1, -1, 0, 'Not Available')**
# - **and in column of Style**

# %%
df
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
# first call fillna, inner it creat python dictionary.
# The key of dic will be    -> The Name of column.
# The value of dic will be  -> the val you want.

# reassign in new var. to store changes.
df2 = df.fillna({"Style": 'Not available',
          "Top Ten" : -1})


# now the Null value in style column will be -> Not available
# and the Null value in Top Ten column will be -> -1
df2
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
# To see Not available row, which we change it


df2.loc[df2['Style'] == 'Not available']
# Out:
#       Review #   Brand            Variety          Style Country Stars Top Ten
# 2152       428  Kamfen     E Menm Chicken  Not available   China  3.75      -1
# 2442       138    Unif  100 Furong Shrimp  Not available  Taiwan     3      -1

# %% [markdown]
# -------------------------------
#
#
# method
#
#
# -------------------------

# %% [markdown]
# #### value_counts
#
# **this method return count of repeted words in data.**

# %%
df['Style'].value_counts()

# as we see how much for repeted words is repeted.
# Out:
# Style
# Pack    1531
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# Japan            352
# USA              323
# South Korea      309
# Taiwan           224
# Thailand         191
# China            169
# Malaysia         156
# Hong Kong        137
# Indonesia        126
# Singapore        109
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             31
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Myanmar           14
# Nepal             14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Brazil             5
# Cambodia           5
# Poland             4
# Fiji               4
# Holland            4
# Dubai              3
# Sarawak            3
# Sweden             3
# Finland            3
# Estonia            2
# Ghana              2
# Nigeria            1
# United States      1
# Name: count, dtype: int64

# %%
df['Stars'].value_counts()
# Out:
# Stars
# 4          384
# 5          369
# 3.75       350
# 3.5        326
# 3          173
# 3.25       170
# 4.25       143
# 4.5        132
# 2.75        85
# 2           68
# 2.5         67
# 4.75        64
# 1.5         37
# 1.75        27
# 0           26
# 1           26
# 2.25        21
# 0.5         14
# 0.25        11
# 1.25        10
# 5.0         10
# 3.50         9
# 5.00         7
# 4.00         6
# 4.3          4
# Unrated      3
# 3.8          3
# 4.50         3
# 4.0          3
# 1.1          2
# 2.3          2
# 3.0          2
# 2.9          2
# 3.1          2
# 4.125        2
# 2.8          2
# 0.75         1
# 3.3          1
# 3.00         1
# 2.1          1
# 3.125        1
# 2.125        1
# 0.9          1
# 0.1          1
# 3.7          1
# 3.4          1
# 3.6          1
# 2.85         1
# 3.2          1
# 3.65         1
# 1.8          1
# Name: count, dtype: int64

# %% [markdown]
# ### if you looked at result 👆 mybe noticed, 'Unrated', (we know how remove it) | lets look the sec way of to day lesson.
#
# 1) **make that value -> Unrated <- Null (NaN) | then remove it by dropna().**
#
# - **To make it Null, we use replace function**
#
# data[].replace('old_val','New_val')

# %%
df['Stars'] = df['Stars'].replace('Unrated',np.nan)

df['Stars'].value_counts() # to check -> unrated <- was removed by Null
# Out:
# Stars
# 4        384
# 5        369
# 3.75     350
# 3.5      326
# 3        173
# 3.25     170
# 4.25     143
# 4.5      132
# 2.75      85
# 2         68
# 2.5       67
# 4.75      64
# 1.5       37
# 1.75      27
# 0         26
# 1         26
# 2.25      21
# 0.5       14
# 0.25      11
# 5.0       10
# 1.25      10
# 3.50       9
# 5.00       7
# 4.00       6
# 4.3        4
# 3.8        3
# 4.50       3
# 4.0        3
# 1.1        2
# 2.3        2
# 3.0        2
# 2.9        2
# 3.1        2
# 4.125      2
# 2.8        2
# 0.75       1
# 3.3        1
# 3.00       1
# 2.1        1
# 3.125      1
# 2.125      1
# 0.9        1
# 0.1        1
# 3.7        1
# 3.4        1
# 3.6        1
# 2.85       1
# 3.2        1
# 3.65       1
# 1.8        1
# Name: count, dtype: int64

# %%
# to see Null values
df[df['Stars'].isnull()]
# Out:
#      Review #          Brand                                Variety Style  \
# 32       2548         Ottogi  Plain Instant Noodle No Soup Included  Pack
# 122      2458  Samyang Foods                             Sari Ramen  Pack
# 993      1587       Mi E-Zee                          Plain Noodles  Pack
#
#          Country Stars Top Ten
# 32   South Korea   NaN     NaN
# 122  South Korea   NaN     NaN
# 993     Malaysia   NaN     NaN

# %% [markdown]
# -........................
#
# lets remove null val in stars Column
#
# - **supset -> i type the column which have null**
# - **inplace make it True -> To applay changes in mean dataFrame.**

# %%
df.dropna(subset=['Stars'],inplace=True)

# %%
df[df['Stars'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten]
# Index: []

# %% [markdown]
# -------------
#
#
#
# # The End !. 👍 👋
