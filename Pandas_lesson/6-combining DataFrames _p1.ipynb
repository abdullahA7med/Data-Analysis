# %% [markdown]
# # Pandas 🐼
#
#
# **Let's define my data.**
#
# - File descriptions
#
#     - sales_train.csv - the training set. Daily historical data from January 2013 to October 2015.
#     - test.csv - the test set. You need to forecast the sales for these shops and products for November 2015.
#     - sample_submission.csv - a sample submission file in the correct format.
#     - items.csv - supplemental information about the items/products.
#     - item_categories.csv  - supplemental information about the items categories.
#     - shops.csv- supplemental information about the shops.
#
#
# - Data fields
#     - ID - an Id that represents a (Shop, Item) tuple within the test set
#     - shop_id - unique identifier of a shop
#     - item_id - unique identifier of a product
#     - item_category_id - unique identifier of item category
#     - item_cnt_day - number of products sold. You are predicting a monthly amount of this measure
#     - item_price - current price of an item
#     - date - date in format dd/mm/yyyy
#     - date_block_num - a consecutive month number, used for convenience. January 2013 is 0, February 2013 is 1,..., October 2015 is 33
#     - item_name - name of item
#     - shop_name - name of shop
#     - item_category_name - name of item category

# %%
import pandas as pd

# %% [markdown]
# Data link : -> https://www.kaggle.com/c/competitive-data-science-predict-future-sales/data

# %% [markdown]
# **What i learn from this lesson ?**
#
# - how i can combining more than dataFrame in one DataFrame.

# %%
# let's read our data files.

item_cat = pd.read_csv('Predict_Future_Sales/item_categories.csv')
items = pd.read_csv('Predict_Future_Sales/items.csv')
sales = pd.read_csv('Predict_Future_Sales/sales_train.csv')
shops = pd.read_csv('Predict_Future_Sales/shops.csv')

# %% [markdown]
# -.......................
#
# **at the first we study the joining at -> item category & items <-**

# %%
item_cat.head(3)
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2

# %%
items.head(3)
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
#
#    item_category_id
# 0                40
# 1                76
# 2                40

# %% [markdown]
# #### Note:
# **there are 4 types to combining the data**
#
# 1) inner joining
# 2) outer joining
# 3) left joining
# 4) right joining

# %% [markdown]
# ### 1. inner joining :
#
# **To use it -> must found 1 column shered bettwen them. and sorted by same order in two data frame**
#
# the elemint, which not be same order -> will delet it.
#
# - in our case -> item_category_id, which shered.

# %%
# 
# the function which do that is -> merge(df1, df2 , how=joining_type, on=column_join_by-it (shered column))

# %%
a = pd.DataFrame({'cat_name':['Elec','Games','Kitchen'],'cat_id':[0,1,2]})

a
# Out:
#   cat_name  cat_id
# 0     Elec       0
# 1    Games       1
# 2  Kitchen       2

# %%
b=pd.DataFrame({'item_name':['macBook','Painting','Cup'], 'item_id':[0,1,2], 'cat_id':[0,5,2]})
b
# Out:
#   item_name  item_id  cat_id
# 0   macBook        0       0
# 1  Painting        1       5
# 2       Cup        2       2

# %%
pd.merge(a,b, how='inner', on='cat_id')
# Out:
#   cat_name  cat_id item_name  item_id
# 0     Elec       0   macBook        0
# 1  Kitchen       2       Cup        2

# %% [markdown]
# ### 2. outer join
#
# this type opposite the inner
#
# - the elemint, which not be same order -> will add -> NaN <-.

# %%
pd.merge(a,b, how='outer', on='cat_id')
# Out:
#   cat_name  cat_id item_name  item_id
# 0     Elec       0   macBook      0.0
# 1    Games       1       NaN      NaN
# 2  Kitchen       2       Cup      2.0
# 3      NaN       5  Painting      1.0

# %% [markdown]
# ### 3. left join
#
# will keep the elemint which in left side give it NaN
# delet  elemint which in right.

# %%
pd.merge(a,b, how='left', on='cat_id')
# Out:
#   cat_name  cat_id item_name  item_id
# 0     Elec       0   macBook      0.0
# 1    Games       1       NaN      NaN
# 2  Kitchen       2       Cup      2.0

# %% [markdown]
# ### 4. right
# opposite of left

# %%
pd.merge(a,b, how='right', on='cat_id')
# Out:
#   cat_name  cat_id item_name  item_id
# 0     Elec       0   macBook        0
# 1      NaN       5  Painting        1
# 2  Kitchen       2       Cup        2

# %% [markdown]
# -..........................................
#
# **let's back to our data and take a Decision**

# %%
item_cat.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
# i chosse right, becouse need the elemint in them.

df2 = pd.merge(item_cat, items, how='right', on='item_category_id')

# %%
df2.head()
# Out:
#                      item_category_name  item_category_id  \
# 0                            Кино - DVD                40
# 1  Программы - Для дома и офиса (Цифра)                76
# 2                            Кино - DVD                40
# 3                            Кино - DVD                40
# 4                            Кино - DVD                40
#
#                                            item_name  item_id
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4

# %%
# ///////////////////

# %%
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# ...

# %%
# ///////////////////////

# %%
sales
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
pd.merge(shops, sales, how='right', on='shop_id')
# Out:
#                       shop_name  shop_id        date  date_block_num  item_id  \
# 0        Ярославль ТЦ "Альтаир"       59  02.01.2013               0    22154
# 1           Москва ТРК "Атриум"       25  03.01.2013               0     2552
# 2           Москва ТРК "Атриум"       25  05.01.2013               0     2552
# 3           Москва ТРК "Атриум"       25  06.01.2013               0     2554
# 4           Москва ТРК "Атриум"       25  15.01.2013               0     2555
# ...                         ...      ...         ...             ...      ...
# 2935844     Москва ТРК "Атриум"       25  10.10.2015              33     7409
# 2935845     Москва ТРК "Атриум"       25  09.10.2015              33     7460
# 2935846     Москва ТРК "Атриум"       25  14.10.2015              33     7459
# 2935847     Москва ТРК "Атриум"       25  22.10.2015              33     7440
# 2935848     Москва ТРК "Атриум"       25  03.10.2015              33     7460
#
# ...

# %% [markdown]
# ## The End.!
